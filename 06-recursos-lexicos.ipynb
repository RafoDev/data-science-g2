# %% [markdown]
# # Stopwords
#
# En español: el la de que y ser estar
#
# Se eliminan porque asi reducimos el ruido en el análisis, nos enfocamos en las palabras que transmiten el significado del texto.
#
# "el perro esta en la casa" -> perro casa

# %%
import nltk
nltk.download("book")
from nltk.book import *
from nltk.corpus import stopwords

# %%
vocabulario_stopw = sorted(set(text1))
vocabulario_stopw

# %%
word_freq= FreqDist(text1)
word_freq
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
stop_words = stopwords.words("english")
content = [w for w in text1 if w.lower() not in stop_words]
len(content)/len(text1)
# Out:
# 0.5862954769399469

# %% [markdown]
# # Swadesh
#
# Listas de palabras en diferentes idiomas

# %%
from nltk.corpus import swadesh
swadesh.fileids()

# %%
traductor_es_en = swadesh.entries(["es","en"])
traductor_es_en

# %%
traductor = dict(traductor_es_en)
traductor

# %%
traductor["perro"]
# Out:
# 'dog'
