# %%
import nltk

# %% [markdown]
# ## Descargar Corpus CESS_ESP
# Es un corpus de texto en español

# %%
nltk.download("cess_esp")

# %% [markdown]
# ## Generar un corpus

# %%
corpus = nltk.corpus.cess_esp.sents() # sents divide el corpus en oraciones (sentences)
corpus

# %%
len(corpus)

# %%
corpus[6]

# %%
total_corpus = [w for l in corpus for w in l]
print(total_corpus)
# Out:
# ['El', 'grupo', 'estatal', 'Electricité_de_France', '-Fpa-', 'EDF', '-Fpt-', 'anunció', 'hoy', ',', 'jueves', ',', 'la', 'compra', 'del', '51_por_ciento', 'de', 'la', 'empresa', 'mexicana', 'Electricidad_Águila_de_Altamira', '-Fpa-', 'EAA', '-Fpt-', ',', 'creada', 'por', 'el', 'japonés', 'Mitsubishi_Corporation', 'para', 'poner_en_marcha', 'una', 'central', 'de', 'gas', 'de', '495', 'megavatios', '.', 'Una', 'portavoz', 'de', 'EDF', 'explicó', 'a', 'EFE', 'que', 'el', 'proyecto', 'para', 'la', 'construcción', 'de', 'Altamira_2', ',', 'al', 'norte', 'de', 'Tampico', ',', 'prevé', 'la', 'utilización', 'de', 'gas', 'natural', 'como', 'combustible', 'principal', 'en', 'una', 'central', 'de', 'ciclo', 'combinado', 'que', 'debe', 'empezar', 'a', 'funcionar', 'en', 'mayo_del_2002', '.', 'La', 'electricidad', 'producida', 'pasará', 'a', 'la', 'red', 'eléctrica', 'pública', 'de', 'México', 'en_virtud_de', 'un', 'acuerdo', 'de', 'venta', 'de', 'energía', 'de', 'EAA', 'con', 'la', 'Comisión_Fed
# ...

# %%
len(total_corpus)
# Out:
# 192686

# %% [markdown]
# # Expresiones Regulares

# %%
import re

# %%
arr = [w for w in total_corpus if re.search("es", w)]
print(arr)
# Out:
# ['estatal', 'jueves', 'empresa', 'centrales', 'francesa', 'japonesa', 'millones', 'millones', 'dólares', 'millones', 'millones', 'dólares', 'es', 'alcaldesa', 'Congreso', 'esta', 'militantes', 'esta', 'eso', 'es', 'militantes', 'populares', 'militantes', 'especial', 'confesó', 'especialmente', 'elecciones', 'generales', 'apuesten', 'este', 'estas', 'desde', 'Destacó', 'elecciones', 'generales', 'factores', 'alcaldes', 'Respecto_al', 'resultado', 'elecciones', 'demuestra', 'es', 'es', 'andaluces', 'Congreso_por_Málaga', 'militantes', 'este', 'resultados', 'Congreso', 'martes', 'Endesa_Telecomunicaciones', 'Unión_Fenosa_Inversiones', 'empresas', 'españolas', 'esta', 'gestión', 'acciones', 'este', 'es', 'empresa', 'presta', 'telecomunicaciones', 'Endesa_Telecomunicaciones', 'español', 'Endesa', 'telecomunicaciones', 'Unión_Fenosa_Inversiones', 'es', 'empresa', 'español', 'asesoría', 'telecomunicaciones', 'empresas', 'telecomunicaciones', 'españolas', 'respectivamente', 'es', 'empresa', 
# ...

# %%
arr = [w for w in total_corpus if re.search("^..j..t..$", w)]
arr
# Out:
# ['tajantes']

# %%
arr = [w for w in total_corpus if re.search("(es)+", w)]
print(arr)
# Out:
# ['estatal', 'jueves', 'empresa', 'centrales', 'francesa', 'japonesa', 'millones', 'millones', 'dólares', 'millones', 'millones', 'dólares', 'es', 'alcaldesa', 'Congreso', 'esta', 'militantes', 'esta', 'eso', 'es', 'militantes', 'populares', 'militantes', 'especial', 'confesó', 'especialmente', 'elecciones', 'generales', 'apuesten', 'este', 'estas', 'desde', 'Destacó', 'elecciones', 'generales', 'factores', 'alcaldes', 'Respecto_al', 'resultado', 'elecciones', 'demuestra', 'es', 'es', 'andaluces', 'Congreso_por_Málaga', 'militantes', 'este', 'resultados', 'Congreso', 'martes', 'Endesa_Telecomunicaciones', 'Unión_Fenosa_Inversiones', 'empresas', 'españolas', 'esta', 'gestión', 'acciones', 'este', 'es', 'empresa', 'presta', 'telecomunicaciones', 'Endesa_Telecomunicaciones', 'español', 'Endesa', 'telecomunicaciones', 'Unión_Fenosa_Inversiones', 'es', 'empresa', 'español', 'asesoría', 'telecomunicaciones', 'empresas', 'telecomunicaciones', 'españolas', 'respectivamente', 'es', 'empresa', 
# ...
