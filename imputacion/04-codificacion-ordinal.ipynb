# %%
# !pip install nhanes
import nhanes.load
# Out:
# Collecting nhanes
#   Downloading nhanes-0.5.1-py3-none-any.whl.metadata (750 bytes)
# Downloading nhanes-0.5.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 24.4 MB/s eta 0:00:00
# Installing collected packages: nhanes
# Successfully installed nhanes-0.5.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install pyjanitor
import janitor
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.29.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (8.4.0)
# Collecting pandas-flavor (from pyjanitor)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pyjanitor) (1.13.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor->pyjanitor) (2024.10.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy->pyjanitor) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-flavor->pyjanitor) (2024.2)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from xarray->pandas-flavor->pyjanitor) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-flavor->pyjanitor) (1.16.0)
# Downloading pyjanitor-0.29.2-py3-none-any.whl (205 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.2/205.2 kB 7.9 MB/s eta 0:00:00
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: pandas-flavor, pyjanitor
# Successfully installed pandas-flavor-0.6.0 pyjanitor-0.29.2

# %%
nhanes.load.load_NHANES_data(year="2017-2018")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          GeneralHealthCondition  EverBreastfedOrFedBreastmilk  \
# SEQN
# 93703.0                     NaN                           1.0
# 93704.0                     NaN                           1.0
# 93705.0                    Good                           NaN
# 93706.0               Very good                           NaN
# 93707.0                    Good                           NaN
# ...                         ...                           ...
# 102952.0              Very good                           NaN
# 102953.0                Fair or                           NaN
# 102954.0                   Good                           NaN
# 102955.0              Very good                           NaN
# 102956.0                   Good                           NaN
#
#           AgeStoppedBreastfeedingdays  AgeFirstFedFormuladays  \
# SEQN
# 93703.0                         273.0                     1.0
# 93704.0                          60.0                     3.0
# 93705.0                           NaN                     NaN
# 93706.0                           NaN                     NaN
# 93707.0                           NaN                     NaN
# ...                               ...                     ...
# 102952.0                          NaN                     NaN
# 102953.0                          NaN                     NaN
# 102954.0                          NaN                     NaN
# 102955.0                          NaN                     NaN
# 102956.0                          NaN                     NaN
#
#           AgeStoppedReceivingFormuladays  AgeStartedOtherFoodbeverage  \
# SEQN
# 93703.0                            365.0                        152.0
# 93704.0                            365.0                        126.0
# 93705.0                              NaN                          NaN
# 93706.0                              NaN                          NaN
# 93707.0                              NaN                          NaN
# ...                                  ...                          ...
# 102952.0                             NaN                          NaN
# 102953.0                             NaN                          NaN
# 102954.0                             NaN                          NaN
# 102955.0                             NaN                          NaN
# 102956.0                             NaN                          NaN
#
#           AgeFirstFedMilkdays TypeOfMilkFirstFedWholeMilk  \
# SEQN
# 93703.0                 365.0       Whole or regular milk
# 93704.0                 365.0       Whole or regular milk
# 93705.0                   NaN                         NaN
# 93706.0                   NaN                         NaN
# 93707.0                   NaN                         NaN
# ...                       ...                         ...
# 102952.0                  NaN                         NaN
# 102953.0                  NaN                         NaN
# 102954.0                  NaN                         NaN
# 102955.0                  NaN                         NaN
# 102956.0                  NaN                         NaN
#
#           TypeOfMilkFirstFed2Milk  TypeOfMilkFirstFed1Milk  ...  \
# SEQN                                                        ...
# 93703.0                       NaN                      NaN  ...
# 93704.0                       NaN                      NaN  ...
# 93705.0                       NaN                      NaN  ...
# 93706.0                       NaN                      NaN  ...
# 93707.0                       NaN                      NaN  ...
# ...                           ...                      ...  ...
# 102952.0                      NaN                      NaN  ...
# 102953.0                      NaN                      NaN  ...
# 102954.0                      NaN                      NaN  ...
# 102955.0                      NaN                      NaN  ...
# 102956.0                      NaN                      NaN  ...
#
#           DaysSmokedCigsDuringPast30Days  AvgCigarettesdayDuringPast30Days  \
# SEQN
# 93703.0                              NaN                               NaN
# 93704.0                              NaN                               NaN
# 93705.0                              NaN                               NaN
# 93706.0                              NaN                               NaN
# 93707.0                              NaN                               NaN
# ...                                  ...                               ...
# 102952.0                             NaN                               NaN
# 102953.0                             NaN                               NaN
# 102954.0                             NaN                               NaN
# 102955.0                             NaN                               NaN
# 102956.0                            30.0                              20.0
#
#           TriedToQuitSmoking TimesStoppedSmokingCigarettes  \
# SEQN
# 93703.0                  NaN                           NaN
# 93704.0                  NaN                           NaN
# 93705.0                  NaN                           NaN
# 93706.0                  NaN                           NaN
# 93707.0                  NaN                           NaN
# ...                      ...                           ...
# 102952.0                 NaN                           NaN
# 102953.0                 NaN                           NaN
# 102954.0                 NaN                           NaN
# 102955.0                 NaN                           NaN
# 102956.0                 1.0                           1.0
#
#          HowLongWereYouAbleToStopSmoking UnitOfMeasureDayweekmonthyear_2_SMQ  \
# SEQN
# 93703.0                              NaN                                 NaN
# 93704.0                              NaN                                 NaN
# 93705.0                              NaN                                 NaN
# 93706.0                              NaN                                 NaN
# 93707.0                              NaN                                 NaN
# ...                                  ...                                 ...
# 102952.0                             NaN                                 NaN
# 102953.0                             NaN                                 NaN
# 102954.0                             NaN                                 NaN
# 102955.0                             NaN                                 NaN
# 102956.0                             2.0                                Days
#
#           CurrentSelfreportedHeightInches  CurrentSelfreportedWeightPounds  \
# SEQN
# 93703.0                               NaN                              NaN
# 93704.0                               NaN                              NaN
# 93705.0                              63.0                            165.0
# 93706.0                              68.0                            145.0
# 93707.0                               NaN                              NaN
# ...                                   ...                              ...
# 102952.0                              NaN                            117.0
# 102953.0                             65.0                            218.0
# 102954.0                             66.0                            150.0
# 102955.0                              NaN                              NaN
# 102956.0                             69.0                            250.0
#
#           TriedToLoseWeightInPastYear  TimesLost10LbsOrMoreToLoseWeight
# SEQN
# 93703.0                           NaN                               NaN
# 93704.0                           NaN                               NaN
# 93705.0                           0.0                  11 times or more
# 93706.0                           0.0                             Never
# 93707.0                           NaN                               NaN
# ...                               ...                               ...
# 102952.0                          0.0                             Never
# 102953.0                          0.0                             Never
# 102954.0                          0.0                             Never
# 102955.0                          NaN                               NaN
# 102956.0                          0.0                            1 to 2
#
# [8366 rows x 197 columns]

# %%
# unaVariableMas -> una_variable_mas
nhanes_raw_df = (
    nhanes.load.load_NHANES_data(year="2017-2018")
    .clean_names(
        case_type="snake"
    )
)
nhanes_raw_df.head(2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         general_health_condition  ever_breastfed_or_fed_breastmilk  \
# SEQN
# 93703.0                      NaN                               1.0
# 93704.0                      NaN                               1.0
#
#          age_stopped_breastfeedingdays  age_first_fed_formuladays  \
# SEQN
# 93703.0                          273.0                        1.0
# 93704.0                           60.0                        3.0
#
#          age_stopped_receiving_formuladays  age_started_other_foodbeverage  \
# SEQN
# 93703.0                              365.0                           152.0
# 93704.0                              365.0                           126.0
#
#          age_first_fed_milkdays type_of_milk_first_fed_whole_milk  \
# SEQN
# 93703.0                   365.0             Whole or regular milk
# 93704.0                   365.0             Whole or regular milk
#
#          type_of_milk_first_fed2_milk  type_of_milk_first_fed1_milk  ...  \
# SEQN                                                                 ...
# 93703.0                           NaN                           NaN  ...
# 93704.0                           NaN                           NaN  ...
#
#          days_smoked_cigs_during_past30_days  \
# SEQN
# 93703.0                                  NaN
# 93704.0                                  NaN
#
#          avg_cigarettesday_during_past30_days  tried_to_quit_smoking  \
# SEQN
# 93703.0                                   NaN                    NaN
# 93704.0                                   NaN                    NaN
#
#         times_stopped_smoking_cigarettes  \
# SEQN
# 93703.0                              NaN
# 93704.0                              NaN
#
#         how_long_were_you_able_to_stop_smoking  \
# SEQN
# 93703.0                                    NaN
# 93704.0                                    NaN
#
#         unit_of_measure_dayweekmonthyear_2_smq  \
# SEQN
# 93703.0                                    NaN
# 93704.0                                    NaN
#
#          current_selfreported_height_inches  \
# SEQN
# 93703.0                                 NaN
# 93704.0                                 NaN
#
#          current_selfreported_weight_pounds  \
# SEQN
# 93703.0                                 NaN
# 93704.0                                 NaN
#
#          tried_to_lose_weight_in_past_year  \
# SEQN
# 93703.0                                NaN
# 93704.0                                NaN
#
#          times_lost10_lbs_or_more_to_lose_weight
# SEQN
# 93703.0                                      NaN
# 93704.0                                      NaN
#
# [2 rows x 197 columns]

# %%
nhanes_df = (
    nhanes_raw_df.select_columns(
        "general_health_condition",
        "gender",
        "age_in_years_at_screening"
    ).rename_columns(
        {
           "age_in_years_at_screening" : "age"
        }
    )
)
nhanes_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `jn.select` instead.
#   return method(self._obj, *args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas_flavor/register.py:157: FutureWarning: This function will be deprecated in a 1.x release. Please use `pd.DataFrame.rename` instead.
#   return method(self._obj, *args, **kwargs)
#          general_health_condition  gender   age
# SEQN
# 93703.0                       NaN  Female   2.0
# 93704.0                       NaN    Male   2.0
# 93705.0                      Good  Female  66.0
# 93706.0                 Very good    Male  18.0
# 93707.0                      Good    Male  13.0
# ...                           ...     ...   ...
# 102952.0                Very good  Female  70.0
# 102953.0                  Fair or    Male  42.0
# 102954.0                     Good  Female  41.0
# 102955.0                Very good  Female  14.0
# 102956.0                     Good    Male  38.0
#
# [8366 rows x 3 columns]

# %% [markdown]
# ## Ejemplo de Codificación Ordinal

# %%
import sklearn.compose
import sklearn.preprocessing
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
X = [["perro"], ["gato"], ["gato"], ["conejo"]]
# X = [["Male"], ["Female"], ["Female"]]
X
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['perro'], ['gato'], ['gato'], ['conejo']]

# %%
encoder = sklearn.preprocessing.OrdinalEncoder()
encoder.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[2.],
#        [1.],
#        [1.],
#        [0.]])

# %%
encoder.categories_
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [array(['conejo', 'gato', 'perro'], dtype=object)]

# %%
encoder.inverse_transform([[1],[0],[2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([['gato'],
#        ['conejo'],
#        ['perro']], dtype=object)

# %% [markdown]
# # Ejemplo con Nhanes

# %% [markdown]
# ## Obtenemos los nombres de las variables categóricas

# %%
nhanes_df.dtypes
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# general_health_condition     object
# gender                       object
# age                         float64
# dtype: object

# %%
categorical_columns = nhanes_df.select_dtypes(object).columns
categorical_columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['general_health_condition', 'gender'], dtype='object')

# %% [markdown]
# ## Creamos un transformador para la codificación ordinal del dataset

# %%
categorical_transformer = sklearn.compose.make_column_transformer(
    (sklearn.preprocessing.OrdinalEncoder(), categorical_columns),
    remainder="passthrough"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Aplicamos el transformador a nuestro dataframe

# %%
nhanes_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          general_health_condition  gender   age
# SEQN
# 93703.0                       NaN  Female   2.0
# 93704.0                       NaN    Male   2.0
# 93705.0                      Good  Female  66.0
# 93706.0                 Very good    Male  18.0
# 93707.0                      Good    Male  13.0
# ...                           ...     ...   ...
# 102952.0                Very good  Female  70.0
# 102953.0                  Fair or    Male  42.0
# 102954.0                     Good  Female  41.0
# 102955.0                Very good  Female  14.0
# 102956.0                     Good    Male  38.0
#
# [8366 rows x 3 columns]

# %%
nhanes_transformed_df = (
    pd.DataFrame(
        categorical_transformer.fit_transform(nhanes_df),
        columns = categorical_transformer.get_feature_names_out(),
        index = nhanes_df.index
    )
    .rename_columns(
        function = lambda x: x.removeprefix("ordinalencoder__")
    )
    .rename_columns(
        function = lambda x: x.removeprefix("remainder__")
    )
)

nhanes_transformed_df

# %%
categorical_transformer.named_transformers_["ordinalencoder"].categories_
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [array(['Excellent', 'Fair or', 'Good', 'Poor?', 'Very good', nan],
#        dtype=object),
#  array(['Female', 'Male'], dtype=object)]
