# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
# %run "/content/pandas_missing_extension.ipynb"

# %%
tiktok_df = pd.read_csv("/content/tiktok_dataset.csv")
tiktok_df.missing.missing_variable_plot()

# %%
(
    tiktok_df.missing.sort_variables_by_missingness().pipe(missingno.matrix)
)
# Out:
# <Axes: >
