# %%
import pandas as pd
df_books = pd.read_csv("/content/drive/MyDrive/bootcamp-ds/pandas/Data/libros.csv")

# %% [markdown]
# **Dataframe.head** [📎](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
#
# Retorna las n primeras filas.

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# Slicing

# %%
df_books[0:4]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
df_books[["Name"]]
# Out:
#                                                   Name
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
# [550 rows x 1 columns]

# %%
df_books[["Name", "Author"]]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %% [markdown]
# **Dataframe.loc**
#
# Sirve para seleccionar datos dentro de un Dataframe. Es muy versatil, permite acceder a files y columnas usando etiquetas/índices.

# %%
# Seleccionar una fila por su índice
df_books.loc[1]
# Out:
# Name           11/22/63: A Novel
# Author              Stephen King
# User Rating                  4.6
# Reviews                     2052
# Price                         22
# Year                        2011
# Genre                    Fiction
# Name: 1, dtype: object

# %%
df_books.loc[[0,5]]
# Out:
#                                             Name               Author  \
# 0                  10-Day Green Smoothie Cleanse             JJ Smith
# 5  A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
#
#    User Rating  Reviews  Price  Year        Genre
# 0          4.7    17350      8  2016  Non Fiction
# 5          4.4    12643     11  2011      Fiction

# %%
df_books.loc[:, "Price"]
# Out:
# 0       8
# 1      22
# 2      15
# 3       6
# 4      12
#        ..
# 545     8
# 546     8
# 547     8
# 548     8
# 549     8
# Name: Price, Length: 550, dtype: int64

# %%
df_books.loc[0, "Price"]
# Out:
# 8

# %%
df_books.loc[:, "Reviews"] * -1
# Out:
# 0      17349
# 1       2051
# 2      18978
# 3      21423
# 4       7664
#        ...
# 545     9412
# 546    14330
# 547    14330
# 548    14330
# 549    14330
# Name: Reviews, Length: 550, dtype: int64

# %%
df_books.loc[:, ["Author"]] == "Stephen King"
# Out:
#      Author
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %% [markdown]
# **Dataframe.iloc**
#
# Selecciona datos de un DataFrame o Serie basado en posiciones numéricas.
# No se tiene en cuenta las etiquetas.

# %%
df_books.iloc[0:2, 0]
# Out:
# 0    10-Day Green Smoothie Cleanse
# 1                11/22/63: A Novel
# Name: Name, dtype: object

# %%
df_books.iloc[:2, 2:5]
# Out:
#    User Rating  Reviews  Price
# 0          4.7    17350      8
# 1          4.6     2052     22
