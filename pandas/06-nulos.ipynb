# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "col1":[1,2,3,np.nan],
    "col2":[4, np.nan, 6, 7],
    "col3":["a", "b","c", None]
})
df
# Out:
#    col1  col2  col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %% [markdown]
# Dataframe.isnull

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %%
df.isnull() * 1
# Out:
#    col1  col2  col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %%
df.isnull()["col1"].sum()
# Out:
# 1

# %%
df[df.isnull()["col1"]]
# Out:
#    col1  col2  col3
# 3   NaN   7.0  None

# %% [markdown]
# Completar Nulos

# %%
df.fillna("Missing")
# Out:
#       col1     col2     col3
# 0      1.0      4.0        a
# 1      2.0  Missing        b
# 2      3.0      6.0        c
# 3  Missing      7.0  Missing

# %% [markdown]
# Interpolar

# %%
df.interpolate()
# Out:
# <ipython-input-9-11c47216a02d>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#    col1  col2  col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %% [markdown]
# Borrar nulos

# %%
df.dropna()
# Out:
#    col1  col2 col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c
