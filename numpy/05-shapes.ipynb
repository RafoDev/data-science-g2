# %%
import numpy as np

# %% [markdown]
# Shape

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[2, 9],
#        [8, 4],
#        [8, 7]])

# %%
# Número de dimensiones
arr.ndim
# Out:
# 2

# %%
# Cuales son las dimensiones
arr.shape
# Out:
# (3, 2)

# %% [markdown]
# Reshape

# %%
# anterior shape (3,2)
# nuevo shape (1,6)
arr.reshape(1,6)
# Out:
# array([[2, 9, 8, 4, 8, 7]])
