# %%
import numpy as np

# %% [markdown]
# Scalar - 0 dimensiones

# %%
scalar = np.array(42)
scalar
# Out:
# array(42)

# %%
scalar.ndim
# Out:
# 0

# %% [markdown]
# Vector - 1 dimensión ó arreglo unidimensional

# %%
vector = np.array([1,2,3])
vector
# Out:
# array([1, 2, 3])

# %%
vector.ndim
# Out:
# 1

# %% [markdown]
# Matriz - 2 dimensiones

# %%
matriz = np.array([[1,2,3], [4,5,6]])
print(matriz, matriz.ndim)
# Out:
# [[1 2 3]
#  [4 5 6]] 2

# %% [markdown]
# Tensor - n dimensiones

# %%
tensor = np.array([[[[[[[[[1]]]]]]]]])
tensor
# Out:
# array([[[[[[[[[1]]]]]]]]])

# %%
tensor.ndim
# Out:
# 9
