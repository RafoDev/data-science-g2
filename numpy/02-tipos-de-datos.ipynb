# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr_float = np.array([1,2,3,4], dtype="float64")
arr_float
# Out:
# array([1., 2., 3., 4.])

# %%
arr1 = np.array([1,"holaaa",3,"4"])
arr1
# Out:
# array(['1', 'holaaa', '3', '4'], dtype='<U21')

# %% [markdown]
# Cambiar el tipo de dato de un array

# %%
arr = np.array([0, 1, 2, 3, 4])
arr_bool = arr.astype(np.bool_)
arr_bool
# Out:
# array([False,  True,  True,  True,  True])

# %%
arr_string = arr.astype(np.string_)
arr_string
# Out:
# array([b'0', b'1', b'2', b'3', b'4'], dtype='|S21')
