# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

penguins_df = sns.load_dataset("penguins")
penguins_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Media o Promedio (mean)

# %%
penguins_df.bill_depth_mm.mean()
# Out:
# 17.151169590643278

# %%
np.mean(penguins_df.bill_depth_mm)
# Out:
# 17.151169590643278

# %% [markdown]
# ## Promedio de todas las variables

# %%
penguins_df.describe()

# %%
penguins_df.mean(numeric_only=True)

# %% [markdown]
# # Mediana

# %%
penguins_df.bill_length_mm.median()
# Out:
# 44.45

# %%
penguins_df.median(numeric_only=True)
# Out:
# bill_length_mm         44.45
# bill_depth_mm          17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# dtype: float64

# %% [markdown]
# # Moda

# %%
penguins_df.bill_depth_mm.mode()

# %%
penguins_df.mode(numeric_only=True)
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            41.1           17.0              190.0       3800.0

# %%
penguins_df.bill_depth_mm.mode()
# Out:
# 0    17.0
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# # Graficamos la media, mediana y moda de una variable

# %%
sns.histplot(
    data=penguins_df,
    x="bill_depth_mm"
)

bill_mean = round(penguins_df.bill_depth_mm.mean(), 2)
bill_median = penguins_df.bill_depth_mm.median()
bill_mode = penguins_df.bill_depth_mm.mode()[0]

#print(bill_mean, bill_median, bill_mode)

plt.axvline(
    x=bill_mean,
    color="red",
    label=f"Media: {bill_mean}",
    linestyle="dashed"
)

plt.axvline(
    x=bill_median,
    color="green",
    label=f"Mediana: {bill_median}",
    linestyle="dashed"
)

plt.axvline(
    x=bill_mode,
    color="yellow",
    label=f"Moda: {bill_mode}",
    linestyle="dashed"
)

plt.legend()
plt.show()
